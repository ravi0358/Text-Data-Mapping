# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
# Out:
# C:\Users\rsure\AppData\Local\Continuum\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df = pd.read_csv('Second_Iteration_NEW.csv')

# %%
del df['Unnamed: 0']

# %%
df.shape
# Out:
# (28, 12)

# %%
df.fillna('NA',inplace=True)

# %%
ids = {'root':['ST','RD','W','AVE','STR','DR','E','S','N','APT','HWY','PL','PO','TER','SW','NE','SE','NW','MN','STR.'],
       'abb':['STREET','ROAD','WEST','AVENUE','STREET','DRIVE','EAST','SOUTH','NORTH','APARTMENT','HIGHWAY','PLACE',
             'POST OFFICE','TERRACE','SOUTH WEST','NORTH EAST','SOUTH EAST','NORTH WEST','MAIN','STREET']}
       
ids = dict(zip(ids['root'], ids['abb']))

# %%
ids
# Out:
# {'ST': 'STREET',
#  'RD': 'ROAD',
#  'W': 'WEST',
#  'AVE': 'AVENUE',
#  'STR': 'STREET',
#  'DR': 'DRIVE',
#  'E': 'EAST',
#  'S': 'SOUTH',
#  'N': 'NORTH',
#  'APT': 'APARTMENT',
#  'HWY': 'HIGHWAY',
#  'PL': 'PLACE',
#  'PO': 'POST OFFICE',
#  'TER': 'TERRACE',
#  'SW': 'SOUTH WEST',
#  'NE': 'NORTH EAST',
#  'SE': 'SOUTH EAST',
#  'NW': 'NORTH WEST',
#  'MN': 'MAIN',
#  'STR.': 'STREET'}

# %%
def Convert(string): 
    li = list(string.split(" ")) 
    return li 

def Map_Normalize(df,feature):
    Feature_1= df.apply(lambda x:Convert(x[feature]),axis=1)
    a=[]
    for i in Feature_1.tolist():
        k=[]
        for j in i:
            k.append(ids.get(j,j))
        a.append(k)
    Feature_df= pd.DataFrame(a)
    Feature_df['merged'] = Feature_df.stack().astype(str).groupby(level=0).agg(' '.join)
    Feature_df= Feature_df['merged']
    df[feature]=Feature_df
    return df

# def Map_Normalizeing(df,features):
#     for i in features:
#         df =Map_Normalize(df,i)
#     return df

# %%
df.head()
# Out:
#    gu_party_id  dunsnumber                          company  \
# 0    328958773   744919899           GCPH AUSTRALIA PTY LTD
# 1     91574590   559108922                     BANK ALBILAD
# 2      7167971   558409133                           CHANEL
# 3     43151126   559146975  ABU DHABI INTERNATIONAL AIRPORT
# 4        96561   315108236             BAYERNWERK NETZ GMBH
#
#                       company_name       city  city_name state  \
# 0           GCPH AUSTRALIA PTY LTD      PERTH      PERTH    WA
# 1                     BANK ALBILAD     RIYADH     RIYADH    NA
# 2                           CHANEL         NA         NA    NA
# 3  ABU DHABI INTERNATIONAL AIRPORT  ABU DHABI  ABU DHABI    NA
# 4             BAYERNWERK NETZ GMBH   BAYREUTH   BAYREUTH    NA
#
#   state_or_province_name                               address  \
# 0                     WA                    80 STIRLING STREET
# 1                     NA  STEEN STREET, AL MALAZ, P.O. BOX 140
# 2                     NA                      ?1 MANAMA CENTER
# 3                     NA           SHEIK MAKTOUM BIN RASHID RD
# 4                     NA                     BERNECKER STR. 70
#
#                                       line_1_address               country  \
# 0                                     80 STIRLING ST             AUSTRALIA
# 1  BANK ALBILAD HEAD OFFICE SITTEEN ST AL-MALAZ D...          SAUDI ARABIA
# 2                                                 NA               BAHRAIN
# 3  SHEIK MAKTOUM BIN RASHID ROAD AIRPORT TERMINAL...  UNITED ARAB EMIRATES
# 4                                    LUITPOLDPLATZ 5               GERMANY
#
#    Map_address
# 0           69
# 1           53
# 2            0
# 3           64
# 4           13

# %%
features = ['address','line_1_address']

# %%
df_1 = Map_Normalize(df,'line_1_address')

# %%
df_1.head()
# Out:
#    gu_party_id  dunsnumber                          company  \
# 0    328958773   744919899           GCPH AUSTRALIA PTY LTD
# 1     91574590   559108922                     BANK ALBILAD
# 2      7167971   558409133                           CHANEL
# 3     43151126   559146975  ABU DHABI INTERNATIONAL AIRPORT
# 4        96561   315108236             BAYERNWERK NETZ GMBH
#
#                       company_name       city  city_name state  \
# 0           GCPH AUSTRALIA PTY LTD      PERTH      PERTH    WA
# 1                     BANK ALBILAD     RIYADH     RIYADH    NA
# 2                           CHANEL         NA         NA    NA
# 3  ABU DHABI INTERNATIONAL AIRPORT  ABU DHABI  ABU DHABI    NA
# 4             BAYERNWERK NETZ GMBH   BAYREUTH   BAYREUTH    NA
#
#   state_or_province_name                               address  \
# 0                     WA                    80 STIRLING STREET
# 1                     NA  STEEN STREET, AL MALAZ, P.O. BOX 140
# 2                     NA                      ?1 MANAMA CENTER
# 3                     NA           SHEIK MAKTOUM BIN RASHID RD
# 4                     NA                     BERNECKER STR. 70
#
#                                       line_1_address               country  \
# 0                                 80 STIRLING STREET             AUSTRALIA
# 1  BANK ALBILAD HEAD OFFICE SITTEEN STREET AL-MAL...          SAUDI ARABIA
# 2                                                 NA               BAHRAIN
# 3  SHEIK MAKTOUM BIN RASHID ROAD AIRPORT TERMINAL...  UNITED ARAB EMIRATES
# 4                                    LUITPOLDPLATZ 5               GERMANY
#
#    Map_address
# 0           69
# 1           53
# 2            0
# 3           64
# 4           13

# %%
df_1['New_Map_Address'] = df_1.apply(lambda x: fuzz.token_sort_ratio(x['address'], x['line_1_address']), axis=1)

# %%
df_1
# Out:
#     gu_party_id  dunsnumber                                    company  \
# 0     328958773   744919899                     GCPH AUSTRALIA PTY LTD
# 1      91574590   559108922                               BANK ALBILAD
# 2       7167971   558409133                                     CHANEL
# 3      43151126   559146975            ABU DHABI INTERNATIONAL AIRPORT
# 4         96561   315108236                       BAYERNWERK NETZ GMBH
# 5     204267070   557753626                    JEDDAH ECONOMIC COMPANY
# 6     265837718   725546621                       SIR RATAN TATA TRUST
# 7     315454578   872305868                  FIRST ABU DHABI BANK PJSC
# 8     281922030   863461637                TVS CREDIT SERVICES LIMITED
# 9     303222328   243454472                  REXALL PHARMACY GROUP LTD
# 10    308386311    80862138  JUSDA SUPPLY CHAIN MANAGEMENT CORPORATION
# 11    180075696   203876657                                     SOBEYS
# 12    334118812    80241034                                    CLARIOS
# 13    317302555   313588967                SEG AUTOMOTIVE GERMANY GMBH
# 14    282442195   577142912                  BRITISH STEEL FRANCE RAIL
# 15    157393782     7374744               GOLDEN TREE ASSET MANAGEMENT
# 16    144109617   109861223                                       TTEC
# 17      4662106   437489222                             BPER BANCA SPA
# 18    276760123   557849918                          FLY ADEAL COMPANY
# 19    231880243   435389100                         KERING EYEWEAR SPA
# 20    282955361   315004531                               MHWIRTH GMBH
# 21      1970093   246350834                                    CLARICA
# 22    315486547     3569865                             CORE & MAIN LP
# 23     11861242    32739207                                    BGI LLC
# 24    275952195   768242240                  SAFRAN HELICOPTER ENGINES
# 25    281426874   265831698                            SAFRAN NACELLES
# 26    327802366   757867858                   CORONADO CURRAGH PTY LTD
# 27    323471133   269238863                              ORANO PROJETS
#
#                                  company_name                    city  \
# 0                      GCPH AUSTRALIA PTY LTD                   PERTH
# 1                                BANK ALBILAD                  RIYADH
# 2                                      CHANEL                      NA
# 3             ABU DHABI INTERNATIONAL AIRPORT               ABU DHABI
# 4                        BAYERNWERK NETZ GMBH                BAYREUTH
# 5                     JEDDAH ECONOMIC COMPANY                  JEDDAH
# 6                        SIR RATAN TATA TRUST                  MUMBAI
# 7                   FIRST ABU DHABI BANK PJSC                  MUMBAI
# 8                 TVS CREDIT SERVICES LIMITED                 CHENNAI
# 9                   REXALL PHARMACY GROUP LTD             MISSISSAUGA
# 10  JUSDA SUPPLY CHAIN MANAGEMENT CORPORATION             DIAMOND BAR
# 11                                     SOBEYS             MISSISSAUGA
# 12                                    CLARIOS             SAN ANTONIO
# 13                SEG AUTOMOTIVE GERMANY GMBH               STUTTGART
# 14                  BRITISH STEEL FRANCE RAIL                 HAYANGE
# 15               GOLDEN TREE ASSET MANAGEMENT                NEW YORK
# 16                                       TTEC                 ORLANDO
# 17                             BPER BANCA SPA                  MODENA
# 18                          FLY ADEAL COMPANY                  JEDDAH
# 19                         KERING EYEWEAR SPA                  PADOVA
# 20                               MHWIRTH GMBH                ERKELENZ
# 21                                    CLARICA                WATERLOO
# 22                             CORE & MAIN LP             THOMASVILLE
# 23                                    BGI LLC        SULLIVANS ISLAND
# 24                  SAFRAN HELICOPTER ENGINES                  TARNOS
# 25                            SAFRAN NACELLES               COLOMIERS
# 26                   CORONADO CURRAGH PTY LTD                BRISBANE
# 27                              ORANO PROJETS  MONTIGNY LE BRETONNEUX
#
#                  city_name state state_or_province_name  \
# 0                    PERTH    WA                     WA
# 1                   RIYADH    NA                     NA
# 2                       NA    NA                     NA
# 3                ABU DHABI    NA                     NA
# 4                 BAYREUTH    NA                     NA
# 5                   JEDDAH    NA                     NA
# 6                   MUMBAI    MH                     MH
# 7                   MUMBAI    MH                     MH
# 8                  CHENNAI    TN                     TN
# 9              MISSISSAUGA    ON                     ON
# 10             DIAMOND BAR    CA                     CA
# 11             MISSISSAUGA    ON                     ON
# 12             SAN ANTONIO    TX                     TX
# 13               STUTTGART    NA                     NA
# 14                 HAYANGE    NA                     NA
# 15                NEW YORK    NY                     NY
# 16                 ORLANDO    FL                     FL
# 17                  MODENA    MO                     MO
# 18                  JEDDAH    NA                     NA
# 19                  PADOVA    PD                     PD
# 20                ERKELENZ    NA                     NA
# 21                WATERLOO    ON                     ON
# 22             THOMASVILLE    GA                     GA
# 23        SULLIVANS ISLAND    SC                     SC
# 24                  TARNOS    NA                     NA
# 25               COLOMIERS    NA                     NA
# 26                BRISBANE   QLD                    QLD
# 27  MONTIGNY LE BRETONNEUX    NA                     NA
#
#                                       address  \
# 0                          80 STIRLING STREET
# 1        STEEN STREET, AL MALAZ, P.O. BOX 140
# 2                            ?1 MANAMA CENTER
# 3                 SHEIK MAKTOUM BIN RASHID RD
# 4                           BERNECKER STR. 70
# 5                          PRINCE SULTAN ROAD
# 6                           24, BOMBAY HOUSE,
# 7      UNIT NO 1101 AND 1201 PLATINA BUILDING
# 8            JAYALAKSHMI ESTATES, THIRD FLOOR
# 9                    3221 DERRY RD W SUITE 16
# 10                    21700 COPLEY DR STE 100
# 11                           2458 DUNDAS ST W
# 12                          5680 E HOUSTON ST
# 13                          LOTTERBERGSTR. 30
# 14                   164 RUE DU MARECHAL FOCH
# 15                          485 LEXINGTON AVE
# 16                          3600 ECOMMERCE PL
# 17                         VIA SAN CARLO 8/20
# 18  UNIT NO: 2, BUILDING 7852, AL MUHAMADIYAH
# 19                         VIA ALTICHIERO 180
# 20                          KÖLNER STR. 71-73
# 21                        485 HUNTERSWOOD CRT
# 22                           1828 METCALF AVE
# 23                               1651 POE AVE
# 24                          ZONE INDUSTRIELLE
# 25                            SAFRAN NACELLES
# 26           L 31 CENTRAL PLZA 1 345 QUEEN ST
# 27                           1 RUE DES HERONS
#
#                                        line_1_address               country  \
# 0                                  80 STIRLING STREET             AUSTRALIA
# 1   BANK ALBILAD HEAD OFFICE SITTEEN STREET AL-MAL...          SAUDI ARABIA
# 2                                                  NA               BAHRAIN
# 3   SHEIK MAKTOUM BIN RASHID ROAD AIRPORT TERMINAL...  UNITED ARAB EMIRATES
# 4                                     LUITPOLDPLATZ 5               GERMANY
# 5                                           JEDDAH,SA          SAUDI ARABIA
# 6                                        BOMBAY HOUSE                 INDIA
# 7   UNNAMED ROAD, G BLOCK BKC, MMRDA AREA, BANDRA ...                 INDIA
# 8                   JAYALAKSHMI ESTATES, THIRD FLOOR,                 INDIA
# 9                 2ND FLOOR - 335 BRITANNIA ROAD EAST                CANADA
# 10                                 21700 COPLEY DRIVE                   USA
# 11                                 3206 ORLANDO DRIVE                CANADA
# 12                                   5050 STOUT DRIVE                   USA
# 13                                      BOERSENSTR. 4               GERMANY
# 14                                164 R MARECHAL FOCH                FRANCE
# 15                                    300 PARK AVENUE                   USA
# 16                                   3402 SHADER ROAD                   USA
# 17                                   V ARISTOTELE 195                 ITALY
# 18             UNIT NO 2 BUILDING 7852 AL MUHAMADIYAH          SAUDI ARABIA
# 19                                   V ALTICHIERO 180                 ITALY
# 20                               KOELNER STREET 71-73               GERMANY
# 21                     227 KING STREET SOUTH STN WATE                CANADA
# 22                                1820 METCALF AVENUE                   USA
# 23                                POST OFFICE BOX 897                   USA
# 24                                5 AVENUE DU 1ER MAI                FRANCE
# 25                                  33 AV JEAN MONNET                FRANCE
# 26                         LEVEL 33 CENTRAL PLAZA 345             AUSTRALIA
# 27                                     1 R DES HERONS                FRANCE
#
#     Map_address  New_Map_Address
# 0            69              100
# 1            53               60
# 2             0               24
# 3            64               64
# 4            13               13
# 5            37               37
# 6            89               89
# 7            29               29
# 8           100              100
# 9            31               28
# 10           79               78
# 11           32               29
# 12           53               55
# 13           57               57
# 14           88               88
# 15           34               31
# 16           32               36
# 17           35               35
# 18          100              100
# 19           94               94
# 20           94               86
# 21           24               24
# 22           94               86
# 23           36               32
# 24           22               22
# 25           25               25
# 26           69               69
# 27           93               93

# %%
df_1.columns
# Out:
# Index(['gu_party_id', 'dunsnumber', 'company', 'company_name', 'city',
#        'city_name', 'state', 'state_or_province_name', 'address',
#        'line_1_address', 'country', 'Map_address', 'New_Map_Address'],
#       dtype='object')

# %% [markdown]
# # Droping Stopwords

# %%
dropWords = ["CORPORATION","LIMITED","CORP","GROUP","PRIVATE","PVT","LTD",".","COMPANY",
             "INC","CO","PTE","TECHNOLOGY","PLC","THE"]

# %%
words = df.company_name.str.split(expand=True).stack()
words = words[words.isin(dropWords)]
words.value_counts()
# Out:
# LTD            3
# COMPANY        2
# CORPORATION    1
# LIMITED        1
# GROUP          1
# dtype: int64

# %%
pat = r'\b(?:{})\b'.format('|'.join(dropWords))

# %%
df['company_name'] = df['company_name'].str.replace(pat, ' ')

# %%
# a=[]
# for i in aaa.tolist():
#     k=[]
#     for j in i:
#         k.append(ids.get(j,j))
#     a.append(k)
# aa=pd.DataFrame(a)

# %%
# a = [1, 2, 3, 4, 1, 5, 3, 2, 6, 1, 1]
# dic = {1:10, 2:20, 3:'foo'}

# print([dic.get(n, n) for n in a])
